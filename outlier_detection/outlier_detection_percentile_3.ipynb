# %% [markdown]
# # Outlier Detection using percentile method
#
# # Author/Created by: Ajay Taneja
#
# # Date: September - October 2022.
#
# # Removal of outliers using percentile methods using the Airbnb dataset (see refernces section for the link to the dataset)

# %% [markdown]
# In this notebook, we will use the Airbnb New York City dataset and remove outliers using the percentile method based on the price per night for a given apartment/home. You can use suitable limits on percentile based on intuition. Your goal is to come up with a new pandas dataframe that doesn't have outliers present in it.

# %%
#Load the dataset

import pandas as pd
df = pd.read_csv("AB_NYC_2019.csv")
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
#We have to remian the outliers using the percentile method. We have to use the price per unit as an indiction
#to detect the outliers

#Firstly, let us use the describe() function to get some statistical information

df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %%
#Looking at the price column, the maximum is $10000 per night and minimum is $0 per night. There seem some 
#outliers in the dataset

# %%
min_threshold, max_threshold = df.price.quantile([0.02, 0.98])
min_threshold, max_threshold
# Out:
# (35.0, 550.0)

# %%
#Let us nw see the data points where the price per night is less than the minimum threshold
df[(df.price < min_threshold)]
# Out:
#              id                                               name    host_id  \
# 469      165824                     Lady only Curtain-divided room     733894
# 747      270315                                Bed-stuy Royal Room    1398639
# 776      278145                 Large Room in a Huge NY apartment.    1452026
# 845      296844                    HISTORIC WILLIAMSBURG, BKLYN #1     839679
# 957      375249                    Enjoy Staten Island Hospitality    1887999
# ...         ...                                                ...        ...
# 48845  36454025                                Private 5 star room  261338177
# 48847  36455321  #6 New Hotel-Like Private Room QUEEN Bed near JFK  263504959
# 48852  36455809            Cozy Private Room in Bushwick, Brooklyn   74162901
# 48867  36473044    The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                       Heaven for you(only for guy)  261338177
#
#          host_name neighbourhood_group       neighbourhood  latitude  \
# 469           Lucy              Queens           Sunnyside  40.74000
# 747         Juliet            Brooklyn  Bedford-Stuyvesant  40.68812
# 776          Heidi              Queens             Astoria  40.77117
# 845          Brady            Brooklyn        Williamsburg  40.71653
# 957    Rimma & Jim       Staten Island        Graniteville  40.62109
# ...            ...                 ...                 ...       ...
# 48845        Diana            Brooklyn           Gravesend  40.59131
# 48847        David              Queens           Woodhaven  40.69183
# 48852    Christine            Brooklyn            Bushwick  40.69805
# 48867        Diana            Brooklyn           Gravesend  40.59080
# 48868        Diana            Brooklyn           Gravesend  40.59118
#
#        longitude     room_type  price  minimum_nights  number_of_reviews  \
# 469    -73.91901  Private room     33              44                 31
# 747    -73.93254  Private room     34              10                 16
# 776    -73.91905  Private room     30               5                  3
# 845    -73.95554  Private room     30               3                 24
# 957    -74.16534  Private room     20               3                 80
# ...          ...           ...    ...             ...                ...
# 48845  -73.97114  Private room     33               2                  0
# 48847  -73.86523  Private room     34               1                  0
# 48852  -73.92801  Private room     30               1                  1
# 48867  -73.97116   Shared room     25               1                  0
# 48868  -73.97119   Shared room     25               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 469    2019-05-01               0.32                               3
# 747    2019-03-27               0.19                               3
# 776    2017-06-20               0.03                               1
# 845    2013-12-04               0.28                               3
# 957    2019-05-26               0.92                               1
# ...           ...                ...                             ...
# 48845         NaN                NaN                               6
# 48847         NaN                NaN                               8
# 48852  2019-07-08               1.00                               1
# 48867         NaN                NaN                               6
# 48868         NaN                NaN                               6
#
#        availability_365
# 469                 161
# 747                 216
# 776                   0
# 845                   0
# 957                 226
# ...                 ...
# 48845               318
# 48847               320
# 48852                 1
# 48867               338
# 48868               365
#
# [964 rows x 16 columns]

# %%
# Similarly, let us the data points where the price is greater than the maximum threshold
df[df.price > max_threshold]
# Out:
#              id                                               name    host_id  \
# 85        19601                perfect for a family or small group      74303
# 299       68974                 Unique spacious loft on the Bowery     281229
# 345       89427                               The Brooklyn Waverly     116599
# 365      103311                  2 BR w/ Terrace @ Box House Hotel     417504
# 496      174966              Luxury 2Bed/2.5Bath Central Park View     836168
# ...         ...                                                ...        ...
# 48523  36308562  Tasteful & Trendy Brooklyn Brownstone, near Train  217732163
# 48535  36311055     Stunning & Stylish Brooklyn Luxury, near Train  245712163
# 48697  36388720         HUGE LUXURY CONDO – INCREDIBLE WATER VIEWS  273619215
# 48757  36419574     Luxury & Spacious 1500 ft² MANHATTAN Townhouse   11454384
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
#
#                  host_name neighbourhood_group       neighbourhood  latitude  \
# 85                  Maggie            Brooklyn    Brooklyn Heights  40.69723
# 299                 Alicia           Manhattan        Little Italy  40.71943
# 345                   Sahr            Brooklyn        Clinton Hill  40.68613
# 365    The Box House Hotel            Brooklyn          Greenpoint  40.73861
# 496                  Henry           Manhattan     Upper West Side  40.77350
# ...                    ...                 ...                 ...       ...
# 48523                Sandy            Brooklyn  Bedford-Stuyvesant  40.68767
# 48535              Urvashi            Brooklyn  Bedford-Stuyvesant  40.68245
# 48697                Layla           Manhattan     Upper West Side  40.77665
# 48757                Ellen           Manhattan             Tribeca  40.71815
# 48839              Richard            Brooklyn      Sheepshead Bay  40.59866
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 85     -73.99268  Entire home/apt    800               1                 25
# 299    -73.99627  Entire home/apt    575               2                191
# 345    -73.96536  Entire home/apt    650               5                  0
# 365    -73.95485     Private room    599               3                  9
# 496    -73.98697  Entire home/apt   2000              30                 30
# ...          ...              ...    ...             ...                ...
# 48523  -73.95805  Entire home/apt   1369               1                  0
# 48535  -73.93417  Entire home/apt   1749               1                  0
# 48697  -73.98867  Entire home/apt    750               4                  0
# 48757  -74.01145  Entire home/apt    700               3                  0
# 48839  -73.95661     Private room    800               1                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 85     2016-08-04               0.24                               1
# 299    2019-06-20               1.88                               1
# 345           NaN                NaN                               3
# 365    2018-05-19               0.09                              28
# 496    2018-05-05               0.33                              11
# ...           ...                ...                             ...
# 48523         NaN                NaN                               1
# 48535         NaN                NaN                               1
# 48697         NaN                NaN                               1
# 48757         NaN                NaN                               1
# 48839         NaN                NaN                               1
#
#        availability_365
# 85                    7
# 299                 298
# 345                 365
# 365                  60
# 496                   0
# ...                 ...
# 48523               349
# 48535               303
# 48697               174
# 48757                37
# 48839                23
#
# [935 rows x 16 columns]

# %%
#Lets keep the minimum and max threshold limited to 2nd percentile
#Let us remove the outliers outside thsi range

df2 = df[(df.price > min_threshold) & (df.price < max_threshold)]
df2.sample(10)
# Out:
#              id                                              name    host_id  \
# 48243  36149281      My Cozy Two Bedroom Apt in Soho - Very Conve    1387341
# 15954  12898943                Beautiful Pre-War on Prospect Park   10259868
# 8092    6244461            Bright studio in the heart of Brooklyn    7290581
# 35730  28355651                 A Cozy Room in New York Apartment  214095681
# 23334  18893669          Master Bedroom w/ TV, AC, King Sized Bed   31314659
# 18862  14968000               Spacious Comtemporary 3BR Apartment   24805685
# 31002  24038323  Dreamy Williamsburg Bedroom with Private Terrace   32720219
# 29390  22545036                       Cozy Room Close to Columbia   12541753
# 6013    4402117                  GORGEOUS 2 Bedroom in Queens NYC   22780462
# 28728  22207770  AWESOME PRIVATE FAMILY HOUSE  CLOSE TO MANHATTAN  155989291
#
#              host_name neighbourhood_group      neighbourhood  latitude  \
# 48243              Dan           Manhattan               SoHo  40.72403
# 15954         Meredith            Brooklyn      Crown Heights  40.66676
# 8092           Juliana            Brooklyn   Prospect Heights  40.67847
# 35730  Pavel And Sarah              Queens          Sunnyside  40.74403
# 23334           Muneer           Manhattan        East Harlem  40.79439
# 18862             Saif            Brooklyn         Park Slope  40.67124
# 31002            Gizem            Brooklyn       Williamsburg  40.70894
# 29390             Yiou           Manhattan    Upper West Side  40.80034
# 6013              Mark              Queens  Kew Gardens Hills  40.72891
# 28728            Ahmed              Queens             Corona  40.74725
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 48243  -73.99700  Entire home/apt    250               2                  0
# 15954  -73.95991     Private room     85               7                  0
# 8092   -73.96694  Entire home/apt    150               2                  2
# 35730  -73.92147     Private room     65               2                 64
# 23334  -73.94129     Private room     75               7                  0
# 18862  -73.98625  Entire home/apt    218               2                117
# 31002  -73.94333     Private room    120               4                 10
# 29390  -73.96127     Private room     39               3                  1
# 6013   -73.82588  Entire home/apt    149               3                 82
# 28728  -73.85486  Entire home/apt    359               3                 10
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 48243         NaN                NaN                               1
# 15954         NaN                NaN                               1
# 8092   2017-01-14               0.06                               1
# 35730  2019-07-01               6.34                               2
# 23334         NaN                NaN                               1
# 18862  2019-07-08               3.41                               1
# 31002  2019-06-17               0.66                               2
# 29390  2018-01-13               0.06                               1
# 6013   2019-06-23               1.55                               2
# 28728  2019-06-09               0.66                               1
#
#        availability_365
# 48243               247
# 15954                 0
# 8092                  0
# 35730                 6
# 23334                 0
# 18862               226
# 31002                 8
# 29390                 0
# 6013                327
# 28728               281

# %%
df2.price.describe()
# Out:
# count    46465.000000
# mean       135.165350
# std         88.602677
# min         36.000000
# 25%         70.000000
# 50%        109.000000
# 75%        175.000000
# max        549.000000
# Name: price, dtype: float64

# %% [markdown]
# References:
# 1) Airbnb dataset from Kaggle: https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data
# 2) Coodebasics: https://youtu.be/7sJaRHF03K8?list=PLeo1K3hjS3ut5olrDIeVXk9N3Q7mKhDxO
